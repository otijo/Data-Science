# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# OBJECTIVES
# >data Science tools
# >data scince and programmimg languages
# >commonly used libraries in data science
# >arithmetic expression
# >time conversion

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2.Scala
# 3.JavaScript
# 4. MATLAB
# 5.Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1.NumPy
# 2.Matplotlib
# 3.SciPy
# 4.Sci-kit Learn

# %% [markdown]
# |Data Science Tools|
# |....................|
# Data mining and Transformation
# Data Analysis and Big data tools
# Model deployment
# Data Visualization

# %% [markdown]
# #table

# %% [markdown]
# #Table

# %% [markdown]
# # table

# %% [markdown]
#  |Data Science Tools|
#  |..................|
#  |Data mining and Transformation Data Analysis and Big data tools|
#  |Model deployment|
#  |Data Visualization|

# %%
2+2
# Out:
# 4

# %%
3*3
# Out:
# 9

# %%
This a simple arithmetic expression to mutiply then add integers.

# %%
(3*4)+5

# %%
   Hour = min // 60
   print("min value in hours:",hour)
n = 200
print("Time in hours :-",convert(n))

# %% [markdown]
# Author
# Joseph Otieno
